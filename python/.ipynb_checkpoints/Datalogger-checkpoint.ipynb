# %% [markdown]
# # Datalogger Analyse

# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
df = pd.read_csv("../data/DATA009.CSV") # diese pfad evtl. anpassen wenn es im colab läuft...
df
# Out:
#         Date      Time  SoilHumidity RAW  SoilHumidity %  Temperature C°  \
# 0   31.01.23  00:01:01               595               2              24
# 1   31.01.23  00:02:01               595               2              23
# 2   31.01.23  00:03:01               595               2              23
# 3   31.01.23  00:04:01               596               1              23
# 4   31.01.23  00:05:01               596               1              23
# 5   31.01.23  00:06:01               595               2              23
# 6   31.01.23  00:07:01               595               2              23
# 7   31.01.23  00:08:01               596               1              23
# 8   31.01.23  00:09:01               596               1              23
# 9   31.01.23  00:10:01               595               2              23
# 10  31.01.23  00:11:01               597               1              23
# 11  31.01.23  00:12:01               595               2              23
#
# ...

# %%
# get averages for all columns
df.mean(axis=0)
# Out:
# /Users/gordan.savicic/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:2: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
# SoilHumidity RAW    595.500000
# SoilHumidity %        1.583333
# Temperature C°       23.083333
# AirPressure hPa     978.726667
#  AirHumidity %       34.333333
# dtype: float64

# %% [markdown]
# # Visualisieren

# %%
# alle werte werden visualisiert
df.plot(subplots=True,figsize=(6, 6))
# Out:
# array([<AxesSubplot:>, <AxesSubplot:>, <AxesSubplot:>, <AxesSubplot:>,
#        <AxesSubplot:>], dtype=object)

# %%
# alle werte in einem graph exportieren
df.plot(figsize=(12, 6)).figure.savefig("data.svg")

# %%
# nur eine spalte visualisieren
ax = df["AirPressure hPa"].plot(figsize=(20, 6))
ax.figure.savefig('data.svg') # ausgabefile speichern PNG oder SVG sind möglich
